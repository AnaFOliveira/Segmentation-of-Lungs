# %%
from segmentation_functions import resample, grow
from .finding_biggest_lung import arrange_slices, normalization, creating_mask
from automaticSeeding import find_seed #confirmar que não é o primeiro metodo
import numpy as np
import os
import matplotlib.pyplot as plt
import scipy.io as spio
import pydicom
import time
from math import sqrt
from segmentation_metrics import compare_volumes_lighter, Dice, Jac, TruePR, VoluM

slices_path = "G:/CTimages/"
indices_path ="G:/Plans/CT/Lungs/ok/Separated Lungs"
seeds_path = "G:/CTimages/CT/Images/Seeds/"
separation_path = "G:/CTimages/CT/Images/Separator/"
centroid_path = "G:/CTimages/CT/Images/Centroids/New_method/"
segmentations_results_path = "G:/Plans/CT/Lungs/segmentation_results/Non_iterative/Centroid/Second_method/"
indices_folder= os.listdir(indices_path)
 
a=0
centroides = np.load(centroid_path+'centroides_all_method2.npy')
metrics = []
TP_list = []
TN_list = []
FP_list = []
FN_list = []
for num,each_mask in enumerate(indices_folder):

    print(num)
    #Loading data--------------------------------------------------------------------------------------------------------
    opened = spio.loadmat(indices_path+'/'+each_mask, squeeze_me=True)["indexes"]
    patient_id = each_mask.split(" ", each_mask.count(each_mask))[0] 
    separador = spio.loadmat(separation_path+'/'+patient_id+'_separator', squeeze_me=True)["separator"]
    pre_region = each_mask.split("_", each_mask.count(each_mask))[1]
    region = pre_region.split("_", pre_region.count(pre_region))[0]
    
    print("Patient-id: "+ str(patient_id))
    print(region)
    
    #Reading the data--------------------------------------------------------------------------------------------------------
    slices= arrange_slices(slices_path,patient_id)
    normalized_volume=normalization(slices)
    normalized_array = np.array(normalized_volume)
    
    #Separating left and right side------------------------------------------------------------------------------------------
    volume = np.zeros(normalized_array.shape) 
    cols = normalized_array.shape[2]
    
    if region =='left':
        volume[:,:,separador:cols] = normalized_array[:,:,separador:cols]
    elif region =='right':
        volume[:,:,0:separador] = normalized_array[:,:,0:separador]
    volume_resampled, spacing = resample(volume, slices, [5,5,5])
    
    #Mask-----------------------------------------------------------------------------------------------------------------
    lung_mask = creating_mask(opened,normalized_array)
    lung_mask_resampled, spacing = resample(lung_mask, slices, [5,5,5])
    ground_truth_boolean = np.where(lung_mask_resampled>0.5, 1, 0)
    
    
    #Centroids--------------------------------------------------------------------------------------------------------------
    
    centroid = tuple(centroides[num])
    
    showing = lung_mask_resampled.copy()
    #showing[tuple(int(centroid[0])]=2
    plt.imshow(showing[:,int(centroid[1]),:])
    plt.scatter([int(centroid[2])], [int(centroid[0])],c='r',s=10)
    plt.show()
    print('centroid: '+str(centroid))
    
    #Segmentation--------------------------------------------------------------------------------------------------------------------

    thresh = 225
    vizinhanca = 1
    first_seg = np.zeros(volume_resampled.shape, dtype=np.bool)
    print('starting segmentation...')
    pre_seed = tuple([int(centroid[0]),int(centroid[1]),int(centroid[2])])
    start = time.time()
    seg, counter = grow(volume_resampled,pre_seed,thresh,1,first_seg)
    result_segment_boolean = np.where(seg==True, 1, 0)
    stop = time.time()
    plt.imshow(seg[:,int(centroid[1]),:])
    plt.show()
    print("Elapsed time: %.3f seconds." % (stop - start))
    a=a+1
    
    #Saving------------------------------------------------------------------------------------------------------------------
    name = segmentations_results_path+"3DVolumeSegmented_"+str(patient_id)+'_'+str(region)+"_"+str(thresh)
    np.save(name, seg)
    
    #Evaluation--------------------------------------------------------------------------------------------------------------
    start=time.time()
    TP, TN, FP, FN = compare_volumes_lighter(ground_truth_boolean,result_segment_boolean)
    stop=time.time()
    TP_list.append(TP)
    FP_list.append(FP)
    TN_list.append(TN)
    FN_list.append(FN)
    
    identification = patient_id+'_'+region
    dice = Dice(TP,FP,FN)
    jac = Jac(TP,FP,FN)
    truePr = TruePR(TP,FN)
    vs = VoluM(TP,FP, FN)
    evaluation =tuple([dice,jac,truePr,vs])
    result = tuple([identification,evaluation])
    metrics.append(result)
    name = segmentations_results_path+"Metrics_Tp_Fp, Tn, Fn"
    np.save(name, metrics)
    print('Metrics:')
    print('Dice: '+str(dice))
    print('Jacquard Index: '+str(jac))
    print('True Positive Rate: '+str(truePr))
    print('Volumetric Similarity: '+str(vs))
    #print('Mutual Information: '+str(mi))
    print('\n'+'-----------------------------------------------------------------------------------------')
    print('----------------------------------------------------------------------------------------------')

    del slices
    del seg
    del normalized_array
    del volume_resampled
# Out:
# 0
# Patient-id: 10194022
# left
# centroid: (48.84629915850936, 70.81229606731925, 78.09848875150266)
# starting segmentation...
# Elapsed time: 0.185 seconds.
# Metrics:
# Dice: 0.013950323239197007
# Jacquard Index: 0.007024156244646223
# True Positive Rate: 0.007041044135325434
# Volumetric Similarity: 0.01871384824770328
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 1
# Patient-id: 10194022
# right
# centroid: (49.2437417654809, 69.20143463621724, 52.34204362465232)
# starting segmentation...
# Elapsed time: 6.146 seconds.
# Metrics:
# Dice: 0.9499865658465436
# Jacquard Index: 0.9047375347272993
# True Positive Rate: 0.9057971014492754
# Volumetric Similarity: 0.9512148313054158
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 2
# Patient-id: 28838683
# left
# centroid: (50.77131072410632, 52.119156736938585, 58.26879010082493)
# starting segmentation...
# Elapsed time: 1.391 seconds.
# Metrics:
# Dice: 0.9596642574026579
# Jacquard Index: 0.9224562976243836
# True Positive Rate: 0.9431714023831348
# Volumetric Similarity: 0.9825134063884355
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 3
# Patient-id: 28838683
# right
# centroid: (51.22861965491373, 50.88859714928732, 36.29913728432108)
# starting segmentation...
# Elapsed time: 1.644 seconds.
# Metrics:
# Dice: 0.9638715860086248
# Jacquard Index: 0.9302626711061783
# True Positive Rate: 0.9431732933233309
# Volumetric Similarity: 0.9780546238620029
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 4
# Patient-id: 31022832
# left
# centroid: (61.04225352112676, 67.51844399731723, 76.29963112005366)
# starting segmentation...
# Elapsed time: 16.446 seconds.
# Metrics:
# Dice: 0.0014435695538057743
# Jacquard Index: 0.0007223061264692364
# True Positive Rate: 0.005533199195171026
# Volumetric Similarity: 0.2608923884514436
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 5
# Patient-id: 31022832
# right
# centroid: (61.74213902618572, 63.10947523398885, 49.32127458197497)
# starting segmentation...
# Elapsed time: 15.773 seconds.
# Metrics:
# Dice: 0.014330660712473358
# Jacquard Index: 0.007217042852469741
# True Positive Rate: 0.03712272583867915
# Volumetric Similarity: 0.3860347102405359
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 6
# Patient-id: 31119444
# left
# centroid: (57.29676777722526, 72.01511685728494, 80.07349577324715)
# starting segmentation...
# Elapsed time: 4.901 seconds.
# Metrics:
# Dice: 0.9550030199315482
# Jacquard Index: 0.9138811289856469
# True Positive Rate: 0.9435106911984088
# Volumetric Similarity: 0.9878196094221864
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 7
# Patient-id: 31119444
# right
# centroid: (57.82155789473684, 70.05717894736843, 52.92244210526316)
# starting segmentation...
# Elapsed time: 5.722 seconds.
# Metrics:
# Dice: 0.9614672579325785
# Jacquard Index: 0.925793881104386
# True Positive Rate: 0.9402947368421053
# Volumetric Similarity: 0.9774831015628364
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 8
# Patient-id: 32064030
# right
# centroid: (178.14659670254315, 50.50821382785248, 36.012551802271844)
# starting segmentation...
# Elapsed time: 22.741 seconds.
# Metrics:
# Dice: 0.9607432008448247
# Jacquard Index: 0.9244521677662583
# True Positive Rate: 0.9357800900390567
# Volumetric Similarity: 0.9733237423284715
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 9
# Patient-id: 32407507
# left
# centroid: (64.3037205770691, 54.29400151860288, 61.967046317388004)
# starting segmentation...
# Elapsed time: 1.895 seconds.
# Metrics:
# Dice: 0.9641997359633455
# Jacquard Index: 0.9308741940320888
# True Positive Rate: 0.9427486712224753
# Volumetric Similarity: 0.9772462530092413
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 10
# Patient-id: 32407507
# right
# centroid: (63.94787998309621, 53.280462036906606, 36.72390477532047)
# starting segmentation...
# Elapsed time: 2.072 seconds.
# Metrics:
# Dice: 0.9586729174179589
# Jacquard Index: 0.9206261255021471
# True Positive Rate: 0.9361881955204958
# Volumetric Similarity: 0.9759826902271908
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 11
# Patient-id: 33515150
# left
# centroid: (70.99014972419228, 51.02186761229314, 64.82860520094563)
# starting segmentation...
# Elapsed time: 3.573 seconds.
# Metrics:
# Dice: 0.9701418510068446
# Jacquard Index: 0.9420150260065498
# True Positive Rate: 0.9633569739952719
# Volumetric Similarity: 0.9929570479119135
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 12
# Patient-id: 33515150
# right
# centroid: (69.92942965779467, 48.98768060836502, 38.40380228136882)
# starting segmentation...
# Elapsed time: 4.314 seconds.
# Metrics:
# Dice: 0.9679031037093111
# Jacquard Index: 0.9378025524424234
# True Positive Rate: 0.9723193916349809
# Volumetric Similarity: 0.9954579863739591
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 13
# Patient-id: 34332375
# left
# centroid: (128.73211129834368, 55.711725781924294, 67.5042127327278)
# starting segmentation...
# Elapsed time: 14.859 seconds.
# Metrics:
# Dice: 0.9546723494938733
# Jacquard Index: 0.9132757074125418
# True Positive Rate: 0.9205951255599852
# Volumetric Similarity: 0.9629834842834311
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 14
# Patient-id: 34332375
# right
# centroid: (130.8017635270541, 54.41523046092184, 32.65551102204409)
# starting segmentation...
# Elapsed time: 14.971 seconds.
# Metrics:
# Dice: 0.9580599617971929
# Jacquard Index: 0.9194962537860673
# True Positive Rate: 0.9247294589178356
# Volumetric Similarity: 0.9639564820197658
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 15
# Patient-id: 35196645
# right
# centroid: (56.49269914702906, 67.91448604886511, 52.045323116958215)
# starting segmentation...
# Elapsed time: 6.641 seconds.
# Metrics:
# Dice: 0.9290467289719626
# Jacquard Index: 0.8674951130969003
# True Positive Rate: 0.8982217724447015
# Volumetric Similarity: 0.9656822429906542
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 16
# Patient-id: 35939665
# left
# centroid: (41.043692385402196, 47.94835206465463, 63.73140548048996)
# starting segmentation...
# Elapsed time: 2.355 seconds.
# Metrics:
# Dice: 0.9620041215868109
# Jacquard Index: 0.9267899243082268
# True Positive Rate: 0.9431746432630382
# Volumetric Similarity: 0.9800360638845955
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 17
# Patient-id: 35939665
# right
# centroid: (42.72790392193657, 45.909082379433286, 35.95796584725089)
# starting segmentation...
# Elapsed time: 3.270 seconds.
# Metrics:
# Dice: 0.9654880173266162
# Jacquard Index: 0.933278718368833
# True Positive Rate: 0.9620003753049352
# Volumetric Similarity: 0.9963745939074344
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 18
# Patient-id: 36319905
# left
# centroid: (152.17501525113536, 51.43347115840846, 65.4506879956619)
# starting segmentation...
# Elapsed time: 10.524 seconds.
# Metrics:
# Dice: 0.9158851946575731
# Jacquard Index: 0.8448230668414155
# True Positive Rate: 0.8738561648478276
# Volumetric Similarity: 0.9519039499857914
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 19
# Patient-id: 36319905
# right
# centroid: (154.86806894205694, 50.0771629436444, 39.74481233699966)
# starting segmentation...
# Elapsed time: 11.095 seconds.
# Metrics:
# Dice: 0.9553409423470881
# Jacquard Index: 0.9145002241147467
# True Positive Rate: 0.9253883660278943
# Volumetric Similarity: 0.9676324261047703
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 20
# Patient-id: 36778909
# left
# centroid: (48.64845862628448, 68.82855597620335, 76.29277086713539)
# starting segmentation...
# Elapsed time: 4.312 seconds.
# Metrics:
# Dice: 0.9664587288671911
# Jacquard Index: 0.9350944716585025
# True Positive Rate: 0.9635839192356228
# Volumetric Similarity: 0.9970165446162191
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 21
# Patient-id: 36778909
# right
# centroid: (48.10462949691845, 65.44818689981368, 52.97893077253834)
# starting segmentation...
# Elapsed time: 5.262 seconds.
# Metrics:
# Dice: 0.9685352622061483
# Jacquard Index: 0.9389901823281908
# True Positive Rate: 0.9595814820123262
# Volumetric Similarity: 0.9906690777576853
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 22
# Patient-id: 36873387
# left
# centroid: (44.60857980282441, 54.89865885069722, 64.49267252864375)
# starting segmentation...
# Elapsed time: 3.509 seconds.
# Metrics:
# Dice: 0.9654326595503067
# Jacquard Index: 0.9331752722163681
# True Positive Rate: 0.9438671285194067
# Volumetric Similarity: 0.9771519418578242
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 23
# Patient-id: 36873387
# right
# centroid: (44.89297754823901, 53.748583315400616, 35.91966143031346)
# starting segmentation...
# Elapsed time: 4.562 seconds.
# Metrics:
# Dice: 0.9601342232921181
# Jacquard Index: 0.9233251490705016
# True Positive Rate: 0.9441216555483825
# Volumetric Similarity: 0.9830397198818251
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 24
# Patient-id: 37017626
# left
# centroid: (125.24876766348997, 53.918961551100885, 63.11666118961551)
# starting segmentation...
# Elapsed time: 9.550 seconds.
# Metrics:
# Dice: 0.9227138643067847
# Jacquard Index: 0.8565169769989047
# True Positive Rate: 0.8737430167597765
# Volumetric Similarity: 0.943952802359882
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 25
# Patient-id: 37017626
# right
# centroid: (126.12554965188714, 51.60887687797728, 32.62866434591425)
# starting segmentation...
# Elapsed time: 13.687 seconds.
# Metrics:
# Dice: 0.9560042507970244
# Jacquard Index: 0.9157166123778502
# True Positive Rate: 0.9271253206302675
# Volumetric Similarity: 0.9688511040264494
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 26
# Patient-id: 37018208
# left
# centroid: (48.076235541535226, 51.75, 62.04468980021031)
# starting segmentation...
# Elapsed time: 1.188 seconds.
# Metrics:
# Dice: 0.8636486122338992
# Jacquard Index: 0.7600189708323453
# True Positive Rate: 0.842534174553102
# Volumetric Similarity: 0.9749393694421988
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 27
# Patient-id: 37018208
# right
# centroid: (48.0874492195852, 50.249091297840494, 39.823391062647)
# starting segmentation...
# Elapsed time: 1.395 seconds.
# Metrics:
# Dice: 0.9456112008616048
# Jacquard Index: 0.8968335035750766
# True Positive Rate: 0.93863587769938
# Volumetric Similarity: 0.9925686591276252
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 28
# Patient-id: 37042652
# left
# centroid: (50.52490638829003, 65.4250538976512, 80.41665721093838)
# starting segmentation...
# Elapsed time: 3.797 seconds.
# Metrics:
# Dice: 0.9522638083523692
# Jacquard Index: 0.9088774597495528
# True Positive Rate: 0.9223873822761829
# Volumetric Similarity: 0.967609676096761
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 29
# Patient-id: 37042652
# right
# centroid: (50.34287041337669, 64.74222015791918, 50.99591267998142)
# starting segmentation...
# Elapsed time: 5.581 seconds.
# Metrics:
# Dice: 0.9568806033869361
# Jacquard Index: 0.9173260572987721
# True Positive Rate: 0.9369252206223874
# Volumetric Similarity: 0.978701200132821
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 30
# Patient-id: 37137615
# left
# centroid: (45.329016592472684, 51.637798462161065, 62.108255766895994)
# starting segmentation...
# Elapsed time: 2.727 seconds.
# Metrics:
# Dice: 0.9521859322207433
# Jacquard Index: 0.9087355872581591
# True Positive Rate: 0.9409146094698503
# Volumetric Similarity: 0.9880208866591584
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 31
# Patient-id: 37137615
# right
# centroid: (45.645185406698566, 49.432864832535884, 37.954395933014354)
# starting segmentation...
# Elapsed time: 3.650 seconds.
# Metrics:
# Dice: 0.956169318522966
# Jacquard Index: 0.9160195570894449
# True Positive Rate: 0.9524521531100478
# Volumetric Similarity: 0.9960972680876614
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 32
# Patient-id: 37173796
# left
# centroid: (40.29988974641676, 51.0877618522602, 63.50330760749724)
# starting segmentation...
# Elapsed time: 4.702 seconds.
# Metrics:
# Dice: 0.9632072789309071
# Jacquard Index: 0.9290258885476086
# True Positive Rate: 0.9337375964718854
# Volumetric Similarity: 0.9684390105203298
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 33
# Patient-id: 37173796
# right
# centroid: (38.51218525634543, 50.19243604004449, 36.894327030033374)
# starting segmentation...
# Elapsed time: 3.725 seconds.
# Metrics:
# Dice: 0.9649150163729924
# Jacquard Index: 0.932208496535101
# True Positive Rate: 0.9386186672059864
# Volumetric Similarity: 0.9719839908519153
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 34
# Patient-id: 37468094
# left
# centroid: (79.50508012988374, 50.43856708913795, 62.18298942076045)
# starting segmentation...
# Elapsed time: 4.024 seconds.
# Metrics:
# Dice: 0.959078869128061
# Jacquard Index: 0.9213751557955961
# True Positive Rate: 0.9291924164659056
# Volumetric Similarity: 0.967836099248608
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 35
# Patient-id: 37468094
# right
# centroid: (80.08950964282626, 49.53783620167776, 36.831531609443914)
# starting segmentation...
# Elapsed time: 4.588 seconds.
# Metrics:
# Dice: 0.9608175651553017
# Jacquard Index: 0.9245898823327321
# True Positive Rate: 0.9309867681397561
# Volumetric Similarity: 0.9679578721885042
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 36
# Patient-id: 37606125
# left
# centroid: (50.67099906044472, 54.13670529282806, 64.20623238333856)
# starting segmentation...
# Elapsed time: 4.834 seconds.
# Metrics:
# Dice: 0.9554240631163708
# Jacquard Index: 0.9146525679758308
# True Positive Rate: 0.9481678672095208
# Volumetric Similarity: 0.9923471400394477
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 37
# Patient-id: 37606125
# right
# centroid: (49.44292489246719, 50.503363846917395, 36.90691518694166)
# starting segmentation...
# Elapsed time: 5.025 seconds.
# Metrics:
# Dice: 0.9599955918007494
# Jacquard Index: 0.9230687718554625
# True Positive Rate: 0.9607367376199405
# Volumetric Similarity: 0.9992285651311439
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 38
# Patient-id: 37624458
# left
# centroid: (138.40853565816818, 53.837092604794975, 63.41613867910183)
# starting segmentation...
# Elapsed time: 12.264 seconds.
# Metrics:
# Dice: 0.9402867081269105
# Jacquard Index: 0.8873029293280947
# True Positive Rate: 0.9043033098484464
# Volumetric Similarity: 0.960208706651207
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 39
# Patient-id: 37624458
# right
# centroid: (141.55231862079975, 51.276837736451434, 35.44899832388858)
# starting segmentation...
# Elapsed time: 16.709 seconds.
# Metrics:
# Dice: 0.8967537642978696
# Jacquard Index: 0.8128319275226492
# True Positive Rate: 0.8306728390134887
# Volumetric Similarity: 0.9204489154083105
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 40
# Patient-id: 37650357
# left
# centroid: (85.99439194898979, 53.93185833909503, 63.797572405316124)
# starting segmentation...
# Elapsed time: 0.025 seconds.
# Metrics:
# Dice: 0.0006143921357806621
# Jacquard Index: 0.00030729046631328263
# True Positive Rate: 0.00030729046631328263
# Volumetric Similarity: 0.0006143921357806281
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 41
# Patient-id: 37650357
# right
# centroid: (83.44220093942536, 52.589458915390715, 39.194534252424816)
# starting segmentation...
# Elapsed time: 6.814 seconds.
# Metrics:
# Dice: 0.9302699228791774
# Jacquard Index: 0.8696305196755783
# True Positive Rate: 0.8829988409687062
# Volumetric Similarity: 0.9464652956298201
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 42
# Patient-id: 37683143
# left
# centroid: (44.405350628293476, 52.55026347790839, 63.25476286988245)
# starting segmentation...
# Elapsed time: 2.234 seconds.
# Metrics:
# Dice: 0.9662390969728065
# Jacquard Index: 0.9346833432598769
# True Positive Rate: 0.9541953790028375
# Volumetric Similarity: 0.9873781426372499
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 43
# Patient-id: 37683143
# right
# centroid: (43.019583407512904, 51.26544418728859, 37.418906889798826)
# starting segmentation...
# Elapsed time: 2.649 seconds.
# Metrics:
# Dice: 0.9626350274482026
# Jacquard Index: 0.9279617616934107
# True Positive Rate: 0.967776393092398
# Volumetric Similarity: 0.9946874446608819
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 44
# Patient-id: 37881605
# left
# C:\Anaconda3\lib\site-packages\scipy\ndimage\interpolation.py:605: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# centroid: (61.59659870165493, 54.19484319283167, 65.60519338026882)
# starting segmentation...
# Elapsed time: 3.358 seconds.
# Metrics:
# Dice: 0.9404899691358025
# Jacquard Index: 0.8876649977241693
# True Positive Rate: 0.89156075706318
# Volumetric Similarity: 0.9451195987654321
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 45
# Patient-id: 37881605
# right
# centroid: (61.51694393099199, 53.036352433764634, 38.25966024117595)
# starting segmentation...
# Elapsed time: 3.671 seconds.
# Metrics:
# Dice: 0.9477981651376147
# Jacquard Index: 0.9007760048827274
# True Positive Rate: 0.9093389666402606
# Volumetric Similarity: 0.9577064220183487
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 46
# Patient-id: 37953385
# left
# centroid: (53.89381839692399, 53.142561372375035, 63.96243714877255)
# starting segmentation...
# Elapsed time: 12.169 seconds.
# Metrics:
# Dice: 0.0011178468549808676
# Jacquard Index: 0.0005592359975909834
# True Positive Rate: 0.003845016267376516
# Volumetric Similarity: 0.29072617051463945
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 47
# Patient-id: 37953385
# right
# centroid: (53.44622675902297, 50.93024668854053, 38.23648073885041)
# starting segmentation...
# Elapsed time: 2.808 seconds.
# Metrics:
# Dice: 0.9423375333622991
# Jacquard Index: 0.890962441314554
# True Positive Rate: 0.9224693158342447
# Volumetric Similarity: 0.9784619204270374
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 48
# Patient-id: 38028657
# left
# centroid: (47.60169838346634, 51.37262124002456, 63.4304276652343)
# starting segmentation...
# Elapsed time: 2.762 seconds.
# Metrics:
# Dice: 0.9648257034859303
# Jacquard Index: 0.9320417892281164
# True Positive Rate: 0.9401473296500921
# Volumetric Similarity: 0.9737505249895002
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 49
# Patient-id: 38028657
# right
# centroid: (47.71138845553822, 49.780637892182355, 34.991939677587105)
# starting segmentation...
# Elapsed time: 3.377 seconds.
# Metrics:
# Dice: 0.9660541887262535
# Jacquard Index: 0.9343373493975904
# True Positive Rate: 0.9409776391055642
# Volumetric Similarity: 0.9733505361035726
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 50
# Patient-id: 38133514
# left
# centroid: (44.47801345059493, 54.34622348680807, 65.5710682876358)
# starting segmentation...
# Elapsed time: 5.493 seconds.
# Metrics:
# Dice: 0.961157105926241
# Jacquard Index: 0.9252189252189252
# True Positive Rate: 0.9496896016554578
# Volumetric Similarity: 0.9879249975457312
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 51
# Patient-id: 38133514
# right
# centroid: (46.15798591706717, 53.374483066949814, 34.089918408405055)
# starting segmentation...
# Elapsed time: 6.496 seconds.
# Metrics:
# Dice: 0.9587556895925833
# Jacquard Index: 0.9207788028320103
# True Positive Rate: 0.9593718564882083
# Volumetric Similarity: 0.9993577392421323
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 52
# Patient-id: 38564873
# left
# centroid: (51.71354000213061, 52.705337168424414, 63.067220624267605)
# starting segmentation...
# Elapsed time: 3.237 seconds.
# Metrics:
# Dice: 0.9361417586091608
# Jacquard Index: 0.8799497171590195
# True Positive Rate: 0.8948545861297539
# Volumetric Similarity: 0.9538615847542627
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 53
# Patient-id: 38564873
# right
# centroid: (49.38066920393276, 49.885585156993336, 33.431176657151916)
# starting segmentation...
# Elapsed time: 4.183 seconds.
# Metrics:
# Dice: 0.9428143961432964
# Jacquard Index: 0.8918153942920041
# True Positive Rate: 0.8993815413891532
# Volumetric Similarity: 0.951708087440778
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 54
# Patient-id: 39002828
# left
# centroid: (139.38001419950302, 57.13613773517927, 67.62442314518992)
# starting segmentation...
# Elapsed time: 7.679 seconds.
# Metrics:
# Dice: 0.916276557436082
# Jacquard Index: 0.8454892839342083
# True Positive Rate: 0.9032658856940007
# Volumetric Similarity: 0.9855959668707238
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 55
# Patient-id: 39002828
# right
# centroid: (136.8092284252911, 54.75459788878006, 42.08200021765154)
# starting segmentation...
# Elapsed time: 11.759 seconds.
# Metrics:
# Dice: 0.8928519561997154
# Jacquard Index: 0.8064431502177449
# True Positive Rate: 0.8363260420067472
# Volumetric Similarity: 0.9324116297307502
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 56
# Patient-id: 39137852
# left
# centroid: (37.42665496489468, 52.368605817452355, 61.66198595787362)
# starting segmentation...
# Elapsed time: 2.586 seconds.
# Metrics:
# Dice: 0.9198473282442748
# Jacquard Index: 0.8515901060070671
# True Positive Rate: 0.8762537612838516
# Volumetric Similarity: 0.9502500658067913
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 57
# Patient-id: 39137852
# right
# centroid: (37.37089052026811, 51.72071496967762, 36.39163740823492)
# starting segmentation...
# Elapsed time: 2.815 seconds.
# Metrics:
# Dice: 0.9582513661202186
# Jacquard Index: 0.9198489299202686
# True Positive Rate: 0.9328651984253644
# Volumetric Similarity: 0.9727868852459016
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 58
# Patient-id: 39256095
# left
# centroid: (129.3288022685331, 60.30125579511185, 64.65908988612324)
# starting segmentation...
# Elapsed time: 13.841 seconds.
# Metrics:
# Dice: 0.9598620914575908
# Jacquard Index: 0.9228219484882418
# True Positive Rate: 0.9273079173605797
# Volumetric Similarity: 0.9648938896265753
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 59
# Patient-id: 39256095
# right
# centroid: (127.677779050674, 59.32084622140757, 37.04792454271203)
# starting segmentation...
# Elapsed time: 19.233 seconds.
# Metrics:
# Dice: 0.9613690007867821
# Jacquard Index: 0.92561169608363
# True Positive Rate: 0.9332111352961393
# Volumetric Similarity: 0.9698269079464988
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 60
# Patient-id: 39524591
# left
# centroid: (47.050353085661655, 52.824992324224745, 59.518268345102854)
# starting segmentation...
# Elapsed time: 2.428 seconds.
# Metrics:
# Dice: 0.9402449955183747
# Jacquard Index: 0.8872286439244432
# True Positive Rate: 0.9662265888854774
# Volumetric Similarity: 0.9731102479832686
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 61
# Patient-id: 39524591
# right
# centroid: (46.316355039759294, 49.71867612293144, 37.33806146572104)
# starting segmentation...
# Elapsed time: 2.915 seconds.
# Metrics:
# Dice: 0.9575113808801214
# Jacquard Index: 0.9184861717612809
# True Positive Rate: 0.9492800343864174
# Volumetric Similarity: 0.9913288532408411
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 62
# Patient-id: 39819471
# left
# centroid: (49.71374816446402, 61.16795154185022, 66.21530837004406)
# starting segmentation...
# Elapsed time: 4.142 seconds.
# Metrics:
# Dice: 0.9623612750885479
# Jacquard Index: 0.9274531221554706
# True Positive Rate: 0.9351138032305433
# Volumetric Similarity: 0.97086186540732
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 63
# Patient-id: 39819471
# right
# centroid: (50.36243005595524, 59.650519584332535, 41.182334132693846)
# starting segmentation...
# Elapsed time: 4.794 seconds.
# Metrics:
# Dice: 0.9595649863036101
# Jacquard Index: 0.9222728701666143
# True Positive Rate: 0.9380495603517186
# Volumetric Similarity: 0.9770636575493683
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 64
# Patient-id: 39844012
# left
# centroid: (32.755591510421624, 49.75168934995717, 65.53868849338537)
# starting segmentation...
# Elapsed time: 3.366 seconds.
# Metrics:
# Dice: 0.9658947776378258
# Jacquard Index: 0.9340391642462288
# True Positive Rate: 0.9487960407347482
# Volumetric Similarity: 0.9819784904563511
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 65
# Patient-id: 39844012
# right
# centroid: (32.412597490674806, 47.04467616141065, 36.730247541539505)
# starting segmentation...
# Elapsed time: 3.877 seconds.
# Metrics:
# Dice: 0.967167019942034
# Jacquard Index: 0.9364215111408947
# True Positive Rate: 0.9476941336046117
# Volumetric Similarity: 0.9794523510836182
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 66
# Patient-id: 39859629
# left
# centroid: (68.10010983838067, 58.28793346932371, 63.82943668601914)
# starting segmentation...
# Elapsed time: 3.322 seconds.
# Metrics:
# Dice: 0.9422511716577965
# Jacquard Index: 0.8908080504656053
# True Positive Rate: 0.9306449082064961
# Volumetric Similarity: 0.9875287949797442
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 67
# Patient-id: 39859629
# right
# centroid: (70.10203589928925, 57.010721599807255, 40.72268401397422)
# starting segmentation...
# Elapsed time: 3.112 seconds.
# Metrics:
# Dice: 0.9609635577516986
# Jacquard Index: 0.9248603019854952
# True Positive Rate: 0.9371160101192627
# Volumetric Similarity: 0.9745521927115504
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 68
# Patient-id: 39929954
# left
# centroid: (44.43586767266396, 52.70032888372993, 63.19800735151867)
# starting segmentation...
# Elapsed time: 4.364 seconds.
# Metrics:
# Dice: 0.9606487239440824
# Jacquard Index: 0.9242772353053801
# True Positive Rate: 0.9339330624879086
# Volumetric Similarity: 0.9713944579871648
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 69
# Patient-id: 39929954
# right
# centroid: (45.333481844508796, 50.60206430533898, 34.68404247419618)
# starting segmentation...
# Elapsed time: 5.964 seconds.
# Metrics:
# Dice: 0.965898266336445
# Jacquard Index: 0.9340456890198968
# True Positive Rate: 0.9411895745154822
# Volumetric Similarity: 0.9737473804534197
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 70
# Patient-id: 39980297
# left
# centroid: (58.421757239190796, 66.34738199127331, 78.05890519635065)
# starting segmentation...
# Elapsed time: 5.344 seconds.
# Metrics:
# Dice: 0.9622000101476483
# Jacquard Index: 0.9271536129852351
# True Positive Rate: 0.9403014676715589
# Volumetric Similarity: 0.9767111471916383
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 71
# Patient-id: 39980297
# right
# centroid: (59.78872572240644, 65.56260855834518, 52.68466761408495)
# starting segmentation...
# Elapsed time: 6.607 seconds.
# Metrics:
# Dice: 0.9645562441770973
# Jacquard Index: 0.9315390032078867
# True Positive Rate: 0.9399968419390494
# Volumetric Similarity: 0.9738728885648317
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 72
# Patient-id: 40165373
# left
# centroid: (60.14818101153505, 65.48244390924071, 77.15743440233236)
# starting segmentation...
# Elapsed time: 4.434 seconds.
# Metrics:
# Dice: 0.9603626943005181
# Jacquard Index: 0.9237478195863443
# True Positive Rate: 0.9397895804284446
# Volumetric Similarity: 0.9781088082901555
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 73
# Patient-id: 40165373
# right
# centroid: (62.33113301383489, 63.48783796003255, 51.899448413057236)
# starting segmentation...
# Elapsed time: 6.956 seconds.
# Metrics:
# Dice: 0.9653414882772681
# Jacquard Index: 0.9330049261083744
# True Positive Rate: 0.9419477348765711
# Volumetric Similarity: 0.9751644889259569
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 74
# Patient-id: 40283713
# left
# centroid: (64.96445069291022, 67.29383410323358, 78.92920265113477)
# starting segmentation...
# Elapsed time: 6.344 seconds.
# Metrics:
# Dice: 0.9699006875477464
# Jacquard Index: 0.9415603678433699
# True Positive Rate: 0.9562161076521389
# Volumetric Similarity: 0.9856888209829386
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 75
# Patient-id: 40283713
# right
# centroid: (66.36985472154964, 65.79384296091318, 51.700363196125906)
# starting segmentation...
# Elapsed time: 8.983 seconds.
# Metrics:
# Dice: 0.9695507195507196
# Jacquard Index: 0.9409009622753981
# True Positive Rate: 0.9554652369422345
# Volumetric Similarity: 0.9852579852579852
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 76
# Patient-id: 40433190
# right
# centroid: (70.79658097005036, 48.057646435197455, 36.996024383779485)
# starting segmentation...
# Elapsed time: 2.714 seconds.
# Metrics:
# Dice: 0.7641439020749365
# Jacquard Index: 0.6183113902645248
# True Positive Rate: 0.6783726477604028
# Volumetric Similarity: 0.8735632183908046
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 77
# Patient-id: 40470341
# left
# centroid: (56.17380173517281, 54.04551272934149, 63.43322429241928)
# starting segmentation...
# Elapsed time: 2.948 seconds.
# Metrics:
# Dice: 0.887033616549686
# Jacquard Index: 0.7969994689325545
# True Positive Rate: 0.8537903569904708
# Volumetric Similarity: 0.9610639083856668
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 78
# Patient-id: 40470341
# right
# centroid: (56.11355815554026, 53.19729295710025, 35.15932553337922)
# starting segmentation...
# Elapsed time: 3.242 seconds.
# Metrics:
# Dice: 0.9366598180217199
# Jacquard Index: 0.8808656287954069
# True Positive Rate: 0.9151181463638449
# Volumetric Similarity: 0.9764602289404168
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 79
# Patient-id: 40584316
# left
# centroid: (76.62632453771037, 52.725742779970915, 64.23696239351756)
# starting segmentation...
# Elapsed time: 6.465 seconds.
# Metrics:
# Dice: 0.9579409246575342
# Jacquard Index: 0.9192769846975455
# True Positive Rate: 0.9298774153334719
# Volumetric Similarity: 0.969820205479452
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 80
# Patient-id: 40584316
# right
# centroid: (77.20129642606868, 52.469866853538896, 35.064646110721796)
# starting segmentation...
# Elapsed time: 9.024 seconds.
# Metrics:
# Dice: 0.9646942267855535
# Jacquard Index: 0.9317964332318399
# True Positive Rate: 0.9382445690259286
# Volumetric Similarity: 0.9718094208772404
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 81
# Patient-id: 41265741
# left
# centroid: (142.7058439793422, 59.3547703180212, 61.360424028268554)
# starting segmentation...
# Elapsed time: 14.456 seconds.
# Metrics:
# Dice: 0.9683157309616454
# Jacquard Index: 0.9385775862068966
# True Positive Rate: 0.9469964664310954
# Volumetric Similarity: 0.9774874930516954
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 82
# Patient-id: 41265741
# right
# centroid: (145.43889845094665, 57.25169852341698, 37.767959054262164)
# starting segmentation...
# Elapsed time: 19.497 seconds.
# Metrics:
# Dice: 0.9636765561372891
# Jacquard Index: 0.9298994072211245
# True Positive Rate: 0.9379019838753511
# Volumetric Similarity: 0.9725189063408959
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 83
# Patient-id: 42242822
# left
# centroid: (47.49110270421746, 57.21087291579095, 63.70982205408435)
# starting segmentation...
# Elapsed time: 12.604 seconds.
# Metrics:
# Dice: 0.002345765892563922
# Jacquard Index: 0.0011742602160638798
# True Positive Rate: 0.007706319181729018
# Volumetric Similarity: 0.30439511227688565
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 84
# Patient-id: 42715988
# left
# centroid: (82.92472915685352, 60.09637305699482, 64.83758831841733)
# starting segmentation...
# Elapsed time: 23.528 seconds.
# Metrics:
# Dice: 0.0007941077207123146
# Jacquard Index: 0.00039721157474528805
# True Positive Rate: 0.0018841262364578427
# Volumetric Similarity: 0.421472672768061
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 85
# Patient-id: 42715988
# right
# centroid: (82.63281036834925, 59.06261937244202, 35.81098226466576)
# starting segmentation...
# Elapsed time: 7.587 seconds.
# Metrics:
# Dice: 0.9569775975954985
# Jacquard Index: 0.9175043559844525
# True Positive Rate: 0.9339017735334243
# Volumetric Similarity: 0.975290951665327
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 86
# Patient-id: 43109032
# left
# centroid: (35.595796676441836, 51.14222873900293, 57.437927663734115)
# starting segmentation...
# Elapsed time: 1.916 seconds.
# Metrics:
# Dice: 0.9508748317631225
# Jacquard Index: 0.9063502245028865
# True Positive Rate: 0.9208211143695014
# Volumetric Similarity: 0.9673620457604307
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 87
# Patient-id: 43109032
# right
# centroid: (37.522632767019125, 48.50730664132114, 30.745039800403944)
# starting segmentation...
# Elapsed time: 2.994 seconds.
# Metrics:
# Dice: 0.9528667117310883
# Jacquard Index: 0.9099765258215963
# True Positive Rate: 0.9211120351669241
# Volumetric Similarity: 0.9655257174460763
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 88
# Patient-id: 43151324
# left
# centroid: (55.95889414332485, 56.46980720261914, 61.128410331029464)
# starting segmentation...
# Elapsed time: 14.886 seconds.
# Metrics:
# Dice: 0.003447209086489592
# Jacquard Index: 0.0017265804852133876
# True Positive Rate: 0.014186977082575483
# Volumetric Similarity: 0.24298404560922793
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 89
# Patient-id: 43151324
# right
# centroid: (56.254137746930056, 52.858622530699414, 36.944260544580885)
# starting segmentation...
# Elapsed time: 3.389 seconds.
# Metrics:
# Dice: 0.9474094273470978
# Jacquard Index: 0.9000740192450037
# True Positive Rate: 0.9089161772557395
# Volumetric Similarity: 0.9576492848795147
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 90
# Patient-id: 43181879
# left
# centroid: (66.35537657199379, 54.46417973717677, 64.23258442843013)
# starting segmentation...
# Elapsed time: 3.097 seconds.
# Metrics:
# Dice: 0.9657789232531501
# Jacquard Index: 0.9338225114218469
# True Positive Rate: 0.9530874664405822
# Volumetric Similarity: 0.9866838487972509
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 91
# Patient-id: 43181879
# right
# centroid: (66.45057471264367, 51.633563218390805, 37.62816091954023)
# starting segmentation...
# Elapsed time: 3.096 seconds.
# Metrics:
# Dice: 0.9656383539191009
# Jacquard Index: 0.9335597057159026
# True Positive Rate: 0.9480459770114943
# Volumetric Similarity: 0.9814435403617632
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 92
# Patient-id: 43266075
# left
# centroid: (54.50766155896069, 67.46835443037975, 79.31445702864757)
# starting segmentation...
# Elapsed time: 3.834 seconds.
# Metrics:
# Dice: 0.9555136155297924
# Jacquard Index: 0.9148167268972638
# True Positive Rate: 0.9444370419720186
# Volumetric Similarity: 0.9882717713669452
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 93
# Patient-id: 43266075
# right
# centroid: (54.9672497208783, 65.42445106066245, 52.8878861183476)
# starting segmentation...
# Elapsed time: 6.918 seconds.
# Metrics:
# Dice: 0.9508429626823262
# Jacquard Index: 0.9062923174144624
# True Positive Rate: 0.9340342389281727
# Volumetric Similarity: 0.9820041674559575
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 94
# Patient-id: 43405561
# left
# centroid: (56.17562268150503, 55.89867514573397, 60.529411764705884)
# starting segmentation...
# Elapsed time: 4.829 seconds.
# Metrics:
# Dice: 0.9597142071997802
# Jacquard Index: 0.922548605240913
# True Positive Rate: 0.9253842077371489
# Volumetric Similarity: 0.9629018961253092
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 95
# Patient-id: 43405561
# right
# centroid: (56.15633621482435, 54.40647415854331, 36.53007173073386)
# starting segmentation...
# Elapsed time: 5.535 seconds.
# Metrics:
# Dice: 0.9557094081942337
# Jacquard Index: 0.9151757333575515
# True Positive Rate: 0.9267059039911716
# Volumetric Similarity: 0.9687025796661608
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 96
# Patient-id: 43675706
# left
# centroid: (55.984248320593004, 66.50173731758166, 76.97868890433172)
# starting segmentation...
# Elapsed time: 4.881 seconds.
# Metrics:
# Dice: 0.9626350274482026
# Jacquard Index: 0.9279617616934107
# True Positive Rate: 0.9444058373870744
# Volumetric Similarity: 0.9806977156012042
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 97
# Patient-id: 43675706
# right
# centroid: (56.000195293428376, 64.88633922468509, 51.35455521921687)
# starting segmentation...
# Elapsed time: 5.833 seconds.
# Metrics:
# Dice: 0.96360450563204
# Jacquard Index: 0.9297652400734229
# True Positive Rate: 0.9397519773459623
# Volumetric Similarity: 0.9746182728410513
#
# ...
# Volumetric Similarity: 0.9696164071401443
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 100
# Patient-id: 44253050
# left
# centroid: (130.47366328761677, 52.10640694361624, 61.88007685682104)
# starting segmentation...
# Elapsed time: 8.114 seconds.
# Metrics:
# Dice: 0.958892875448488
# Jacquard Index: 0.9210319023237495
# True Positive Rate: 0.9296362552176506
# Volumetric Similarity: 0.9685289595079446
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 101
# Patient-id: 44253050
# right
# centroid: (133.55833243563504, 50.83372832058602, 38.983518259183455)
# starting segmentation...
# Elapsed time: 9.619 seconds.
# Metrics:
# Dice: 0.9377049180327869
# Jacquard Index: 0.8827160493827161
# True Positive Rate: 0.8934611655714747
# Volumetric Similarity: 0.9504804974561899
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 102
# Patient-id: 44422897
# left
# centroid: (57.430321592649314, 66.99411622471186, 78.08019666317402)
# starting segmentation...
# Elapsed time: 16.592 seconds.
# Metrics:
# Dice: 0.002108774418649234
# Jacquard Index: 0.0010555001151454672
# True Positive Rate: 0.004432981381478198
# Volumetric Similarity: 0.4757011674942009
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 103
# Patient-id: 44422897
# right
# centroid: (57.08414014069792, 66.07466740962596, 51.10022985303336)
# starting segmentation...
# Elapsed time: 6.753 seconds.
# Metrics:
# Dice: 0.9577424334901088
# Jacquard Index: 0.9189114708921805
# True Positive Rate: 0.9290241693947203
# Volumetric Similarity: 0.9690877104800201
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 104
# Patient-id: 45858788
# left
# centroid: (57.74059650455927, 59.36455167173252, 62.97283434650456)
# starting segmentation...
# Elapsed time: 3.109 seconds.
# Metrics:
# Dice: 0.9617513100543611
# Jacquard Index: 0.9263207547169812
# True Positive Rate: 0.9326557750759878
# Volumetric Similarity: 0.9688035653068221
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 105
# Patient-id: 45858788
# right
# centroid: (59.57489539748954, 57.749182198554585, 36.17649296310384)
# starting segmentation...
# Elapsed time: 3.841 seconds.
# Metrics:
# Dice: 0.9621469588655807
# Jacquard Index: 0.9270551038843722
# True Positive Rate: 0.9368581209585394
# Volumetric Similarity: 0.9730067580764874
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 106
# Patient-id: 46318956
# left
# centroid: (71.01812273465816, 74.84139482564679, 79.54555680539933)
# starting segmentation...
# Elapsed time: 21.262 seconds.
# Metrics:
# Dice: 0.007245011202546224
# Jacquard Index: 0.0036356758574310694
# True Positive Rate: 0.021622297212848394
# Volumetric Similarity: 0.335071298448395
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 107
# Patient-id: 46318956
# right
# centroid: (70.24631600491199, 72.65329512893983, 53.343020875972165)
# starting segmentation...
# Elapsed time: 5.951 seconds.
# Metrics:
# Dice: 0.9418017824546333
# Jacquard Index: 0.8900050735667174
# True Positive Rate: 0.8975644699140402
# Volumetric Similarity: 0.9507140556211747
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 108
# Patient-id: 47262863
# left
# centroid: (48.11940184634165, 53.497215228503855, 66.71740291447318)
# starting segmentation...
# Elapsed time: 4.679 seconds.
# Metrics:
# Dice: 0.9487915111023777
# Jacquard Index: 0.9025721549274712
# True Positive Rate: 0.9209582665751125
# Volumetric Similarity: 0.9697779524464532
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 109
# Patient-id: 47262863
# right
# centroid: (48.048210180623975, 50.946929392446634, 35.146338259441706)
# starting segmentation...
# Elapsed time: 5.197 seconds.
# Metrics:
# Dice: 0.9597642755537492
# Jacquard Index: 0.9226411408478219
# True Positive Rate: 0.9306403940886699
# Volumetric Similarity: 0.968705547652916
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 110
# Patient-id: 47295940
# left
# centroid: (41.56962258927747, 55.19193503737197, 61.93660607179108)
# starting segmentation...
# Elapsed time: 2.972 seconds.
# Metrics:
# Dice: 0.937828883258624
# Jacquard Index: 0.8829357798165137
# True Positive Rate: 0.8880686536864446
# Volumetric Similarity: 0.9439680374196063
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 111
# Patient-id: 47295940
# right
# centroid: (42.65539983511954, 54.874049647339014, 37.54657873042044)
# starting segmentation...
# Elapsed time: 3.134 seconds.
# Metrics:
# Dice: 0.9411540840112269
# Jacquard Index: 0.8888489531853716
# True Positive Rate: 0.906109737107264
# Volumetric Similarity: 0.9613243898958185
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 112
# Patient-id: 48148279
# left
# centroid: (48.23456790123457, 51.522572323567346, 65.30136355260733)
# starting segmentation...
# Elapsed time: 3.521 seconds.
# Metrics:
# Dice: 0.9317202194357367
# Jacquard Index: 0.8721687299403943
# True Positive Rate: 0.8762668140777593
# Volumetric Similarity: 0.9367163009404389
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 113
# Patient-id: 48148279
# right
# centroid: (48.27407169265391, 50.79159299148047, 35.12739109467931)
# starting segmentation...
# Elapsed time: 3.947 seconds.
# Metrics:
# Dice: 0.9333732722837947
# Jacquard Index: 0.8750702078151328
# True Positive Rate: 0.8765471789101431
# Volumetric Similarity: 0.9351705250545594
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 114
# Patient-id: 48259441
# left
# Im zero
# Im zero
# centroid: (87.76299358992146, 140.39809085106972, 151.83913755307046)
# starting segmentation...
# Elapsed time: 139.702 seconds.
# Metrics:
# Dice: 0.9581971008798394
# Jacquard Index: 0.9197489291775545
# True Positive Rate: 0.9474151566445598
# Volumetric Similarity: 0.9886196202798085
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 115
# Patient-id: 48259441
# right
# Im zero
# Im zero
# centroid: (89.60544012089157, 135.63976829114722, 103.64329429542879)
# starting segmentation...
# Elapsed time: 158.134 seconds.
# Metrics:
# Dice: 0.9547576798681114
# Jacquard Index: 0.9134319013677519
# True Positive Rate: 0.9553708600931873
# Volumetric Similarity: 0.9993581757088383
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 116
# Patient-id: 48335198
# right
# centroid: (148.37596677169864, 62.362718418791175, 40.65590088799771)
# starting segmentation...
# Elapsed time: 28.452 seconds.
# Metrics:
# Dice: 0.00011169024571854058
# Jacquard Index: 5.5848241711190124e-05
# True Positive Rate: 0.00021483815525637353
# Volumetric Similarity: 0.5198808637379002
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 117
# Patient-id: 48389421
# left
# centroid: (49.47343425348768, 50.7077767883645, 61.28984861976848)
# starting segmentation...
# Elapsed time: 2.183 seconds.
# Metrics:
# Dice: 0.9586370961553219
# Jacquard Index: 0.9205600589535741
# True Positive Rate: 0.9269813000890472
# Volumetric Similarity: 0.9658506638017036
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 118
# Patient-id: 48389421
# right
# centroid: (50.05872373743964, 49.59571969202662, 38.87015529166123)
# starting segmentation...
# Elapsed time: 2.344 seconds.
# Metrics:
# Dice: 0.9600322971336294
# Jacquard Index: 0.9231366459627329
# True Positive Rate: 0.9309669842098395
# Volumetric Similarity: 0.9687794374915892
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 119
# Patient-id: 48684980
# left
# centroid: (39.28589013694415, 55.32805046930297, 62.09724573011233)
# starting segmentation...
# Elapsed time: 2.159 seconds.
# Metrics:
# Dice: 0.9253425736336431
# Jacquard Index: 0.8610581855488788
# True Positive Rate: 0.9039852284966918
# Volumetric Similarity: 0.9763742321625453
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 120
# Patient-id: 48684980
# right
# centroid: (38.80080838701528, 53.06189213085765, 36.603764052039914)
# starting segmentation...
# Elapsed time: 2.519 seconds.
# Metrics:
# Dice: 0.9608845711363927
# Jacquard Index: 0.9247139869602657
# True Positive Rate: 0.9494758115447771
# Volumetric Similarity: 0.9879841493033363
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 121
# Patient-id: 49174830
# left
# centroid: (58.62702759637666, 57.61122814409101, 61.31377712239309)
# starting segmentation...
# Elapsed time: 3.515 seconds.
# Metrics:
# Dice: 0.9593850515182903
# Jacquard Index: 0.921940486169321
# True Positive Rate: 0.9267958710764693
# Volumetric Similarity: 0.9648367224554326
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 122
# Patient-id: 49174830
# right
# centroid: (58.940711462450594, 56.58216952129995, 38.36908212560387)
# starting segmentation...
# Elapsed time: 3.738 seconds.
# Metrics:
# Dice: 0.9563621715973682
# Jacquard Index: 0.9163736169482803
# True Positive Rate: 0.9384277558190601
# Volumetric Similarity: 0.9808888689970013
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 123
# Patient-id: 51927593
# right
# Im zero
# Im zero
# centroid: (75.52548503781651, 147.00408308670393, 101.22689904636633)
# starting segmentation...
# Elapsed time: 71.369 seconds.
# Metrics:
# Dice: 0.9674680963949625
# Jacquard Index: 0.9369861531804413
# True Positive Rate: 0.9494135700975557
# Volumetric Similarity: 0.9809834966909609
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 124
# Patient-id: 52016057
# left
# centroid: (64.35091319515699, 72.71454955879335, 80.18530679253027)
# starting segmentation...
# Elapsed time: 6.604 seconds.
# Metrics:
# Dice: 0.9574612453677123
# Jacquard Index: 0.9183939120857114
# True Positive Rate: 0.9411040426841781
# Volumetric Similarity: 0.9826191346103659
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 125
# Patient-id: 52016057
# right
# centroid: (63.203977021652676, 71.6152010605391, 50.89023420238621)
# starting segmentation...
# Elapsed time: 8.730 seconds.
# Metrics:
# Dice: 0.952638700947226
# Jacquard Index: 0.9095607235142119
# True Positive Rate: 0.9332744144940345
# Volumetric Similarity: 0.9792512404149752
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 126
# Patient-id: 52075421
# left
# centroid: (41.08460438512869, 56.927669208770254, 62.76155862726406)
# starting segmentation...
# Elapsed time: 2.656 seconds.
# Metrics:
# Dice: 0.9619804400977995
# Jacquard Index: 0.9267459663172771
# True Positive Rate: 0.9376787416587226
# Volumetric Similarity: 0.9740831295843521
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 127
# Patient-id: 52075421
# right
# centroid: (42.274924471299094, 54.473431668740005, 38.273236182690596)
# starting segmentation...
# Elapsed time: 3.638 seconds.
# Metrics:
# Dice: 0.9635269444697729
# Jacquard Index: 0.9296208322336589
# True Positive Rate: 0.9389550382086369
# Volumetric Similarity: 0.9738305826570621
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 128
# Patient-id: 54828475
# left
# centroid: (60.06447746883988, 68.98082454458293, 76.67737296260786)
# starting segmentation...
# Elapsed time: 5.008 seconds.
# Metrics:
# Dice: 0.9586155930533317
# Jacquard Index: 0.9205204021289178
# True Positive Rate: 0.9327660594439118
# Volumetric Similarity: 0.9722872274910703
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 129
# Patient-id: 54828475
# right
# centroid: (61.151059833646364, 65.25436007512745, 52.058760397102226)
# starting segmentation...
# Elapsed time: 5.731 seconds.
# Metrics:
# Dice: 0.9556959107463925
# Jacquard Index: 0.9151509800459121
# True Positive Rate: 0.927019050174403
# Volumetric Similarity: 0.9690655110414458
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 130
# Patient-id: 57220883
# left
# centroid: (43.418199691054625, 52.58151944951552, 65.39432663951692)
# starting segmentation...
# Elapsed time: 3.078 seconds.
# Metrics:
# Dice: 0.9601383983276869
# Jacquard Index: 0.9233328712047691
# True Positive Rate: 0.9352619014183401
# Volumetric Similarity: 0.9734015713976789
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------
# 131
# Patient-id: 57220883
# right
# centroid: (42.62793321299639, 49.25902527075812, 36.17700812274368)
# starting segmentation...
# Elapsed time: 4.599 seconds.
# Metrics:
# Dice: 0.9632331654218054
# Jacquard Index: 0.9290740533899252
# True Positive Rate: 0.9384025270758123
# Volumetric Similarity: 0.9735394592090788
#
# -----------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------

# %%
dice =[]
jac = []
tpr = []
vs = []

for i in metrics:
    #dice = i[1][0]
    dice.append(i[1][0])
    jac.append(i[1][1])
    tpr.append(i[1][2])
    vs.append(i[1][3])
