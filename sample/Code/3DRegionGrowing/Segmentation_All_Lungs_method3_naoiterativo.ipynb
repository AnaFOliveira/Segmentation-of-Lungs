# %%
# %matplotlib inline

# %%
#%%writefile segmentation_3D_thirdversion_naoiterativo.py

from segmentation_functions import resample,grow
from .finding_biggest_lung import arrange_slices, normalization, get_pixels_hu,creating_mask
from seed_evaluation import evaluate_seed
import scipy.ndimage.interpolation as inter
import numpy as np
import os
import matplotlib.pyplot as plt
import scipy.io as spio
import pydicom
import time


slices_path = "G:/CTimages/"
indices_path ="G:/Results/Lungs Masks indexes/ok/Separated Lungs"
separation_path = "G:/Results/Separator/"
segmentations_results_path = "G:/Plans/CT/Lungs/segmentation_results/Non_iterative/third/"
seeds_path = "G:/CTimages/CT/Images/Seeds/"

indices_folder= os.listdir(indices_path)

results = []

for num,each_mask in enumerate(indices_folder):

    print(num)
    #Loading data--------------------------------------------------------------------------------------------------------
    opened = spio.loadmat(indices_path+'/'+each_mask, squeeze_me=True)["indexes"]
    patient_id = each_mask.split(" ", each_mask.count(each_mask))[0] 
    separador = spio.loadmat(separation_path+'/'+patient_id+'_separator', squeeze_me=True)["separator"]
    pre_region = each_mask.split("_", each_mask.count(each_mask))[1]
    region = pre_region.split("_", pre_region.count(pre_region))[0]
    print("Patient-id: "+ str(patient_id))
    print(region)
    
    #Reading the data--------------------------------------------------------------------------------------------------------
    slices= arrange_slices(slices_path,patient_id)
    normalized_volume=normalization(slices)
    normalized_array = np.array(normalized_volume)
    
    #Separating left and right side------------------------------------------------------------------------------------------
    #possible improvement: define non-used side as the minimum of intensity of the volume
    volume = np.zeros(normalized_array.shape)
    cols = normalized_array.shape[2]
    
    if region =='left':
        volume[:,:,separador:cols] = normalized_array[:,:,separador:cols]
    elif region =='right':
        volume[:,:,0:separador] = normalized_array[:,:,0:separador]
    volume_resampled, spacing = resample(volume, slices, [5,5,5])
    

    #Seed--------------------------------------------------------------------------------------------------------------------
    max_seeding = 39705+50
    min_seeding = 3257
    seed_1 = spio.loadmat(seeds_path+'/'+patient_id+'_seed1', squeeze_me=True)["seed1"]
    seed_2 = spio.loadmat(seeds_path+'/'+patient_id+'_seed2', squeeze_me=True)["seed2"]
     
    if region=='left':
        seeds = [seed_2]
    elif region =='right':
        seeds = [seed_1]
    
    mask = creating_mask(seeds,normalized_array)
    mask_resampled, spacing = resample(mask, slices, [5,5,5])
    j = np.unravel_index(np.argmax(mask_resampled), mask_resampled.shape) #tupla
    print('j: '+str(j))
    seeds= [j] #lista

    interval = volume_resampled.copy()
    interval[j]=5000
    plt.imshow(interval[:,j[1],:])
    plt.show()
    
    #evaluation = evaluate_seed(seeds[0], opened, slices, normalized_array, region, patient_id)
    #results.append(evaluation)
    
    
    #Segmentation------------------------------------------------------------------------------------------------------------
    thresh = 225# tentar 300
    vizinhanca = 1
    first_seg = np.zeros(volume_resampled.shape, dtype=np.bool)
    size_seeds = len(seeds)

    if size_seeds>1:
        for i in range(len(seeds)-1):
            start = time.time()
            seg, counter = grow(volume_resampled,seeds[i],thresh,1,first_seg) 
            print('finish:'+str(i))
            first_seg = seg
    else:
        print('starting segmentation...')
        pre_seed = tuple(seeds[0])
        start = time.time()
        seg, counter = grow(volume_resampled,pre_seed,thresh,vizinhanca,first_seg)
        stop = time.time()
    plt.imshow(seg[:,j[1],:])
    plt.show()
    
    del normalized_array
    del volume_resampled
    del volume
    del slices
    print("Elapsed time: %.3f seconds." % (stop - start))
    
    name = segmentations_results_path+"3DVolumeSegmented_"+str(patient_id)+'_'+str(region)+"_"+str(thresh)
    np.save(name, seg)
# Out:
# 0
# Patient-id: 10194022
# left
# j: (42, 77, 79)
# starting segmentation...
# Elapsed time: 7.094 seconds.
# 1
# Patient-id: 10194022
# right
# j: (57, 77, 51)
# starting segmentation...
# Elapsed time: 9.633 seconds.
# 2
# Patient-id: 28838683
# left
# j: (52, 53, 60)
# starting segmentation...
# Elapsed time: 1.399 seconds.
# 3
# Patient-id: 28838683
# right
# j: (57, 53, 36)
# starting segmentation...
# Elapsed time: 2.128 seconds.
# 4
# Patient-id: 31022832
# left
# j: (56, 63, 78)
# starting segmentation...
# Elapsed time: 23.855 seconds.
# 5
# Patient-id: 31022832
# right
# j: (69, 63, 50)
# starting segmentation...
# Elapsed time: 7.079 seconds.
# 6
# Patient-id: 31119444
# left
# j: (55, 72, 80)
# starting segmentation...
# Elapsed time: 9.369 seconds.
# 7
# Patient-id: 31119444
# right
# j: (54, 71, 52)
# starting segmentation...
# Elapsed time: 10.215 seconds.
# 8
# Patient-id: 32064030
# right
# j: (195, 52, 38)
# starting segmentation...
# Elapsed time: 41.671 seconds.
# 9
# Patient-id: 32407507
# left
# j: (64, 58, 63)
# starting segmentation...
# Elapsed time: 2.744 seconds.
# 10
# Patient-id: 32407507
# right
# j: (60, 59, 37)
# starting segmentation...
# Elapsed time: 2.833 seconds.
# 11
# Patient-id: 33515150
# left
# j: (73, 50, 66)
# starting segmentation...
# Elapsed time: 4.744 seconds.
# 12
# Patient-id: 33515150
# right
# j: (73, 50, 38)
# starting segmentation...
# Elapsed time: 5.752 seconds.
# 13
# Patient-id: 34332375
# left
# j: (112, 59, 66)
# starting segmentation...
# Elapsed time: 22.206 seconds.
# 14
# Patient-id: 34332375
# right
# j: (146, 59, 34)
# starting segmentation...
# Elapsed time: 21.468 seconds.
# 15
# Patient-id: 35196645
# right
# j: (58, 68, 52)
# starting segmentation...
# Elapsed time: 9.809 seconds.
# 16
# Patient-id: 35939665
# left
# j: (39, 46, 65)
# starting segmentation...
# Elapsed time: 3.124 seconds.
# 17
# Patient-id: 35939665
# right
# j: (46, 46, 36)
# starting segmentation...
# Elapsed time: 4.348 seconds.
# 18
# Patient-id: 36319905
# left
# j: (156, 51, 66)
# starting segmentation...
# Elapsed time: 12.123 seconds.
# 19
# Patient-id: 36319905
# right
# j: (169, 51, 40)
# starting segmentation...
# Elapsed time: 14.217 seconds.
# 20
# Patient-id: 36778909
# left
# j: (43, 68, 77)
# starting segmentation...
# Elapsed time: 5.692 seconds.
# 21
# Patient-id: 36778909
# right
# j: (53, 68, 53)
# starting segmentation...
# Elapsed time: 7.581 seconds.
# 22
# Patient-id: 36873387
# left
# j: (46, 57, 65)
# starting segmentation...
# Elapsed time: 5.008 seconds.
# 23
# Patient-id: 36873387
# right
# j: (37, 57, 37)
# starting segmentation...
# Elapsed time: 7.246 seconds.
# 24
# Patient-id: 37017626
# left
# j: (125, 52, 66)
# starting segmentation...
# Elapsed time: 12.881 seconds.
# 25
# Patient-id: 37017626
# right
# j: (142, 52, 34)
# starting segmentation...
# Elapsed time: 18.250 seconds.
# 26
# Patient-id: 37018208
# left
# j: (54, 49, 64)
# starting segmentation...
# Elapsed time: 1.560 seconds.
# 27
# Patient-id: 37018208
# right
# j: (53, 49, 39)
# starting segmentation...
# Elapsed time: 1.728 seconds.
# 28
# Patient-id: 37042652
# left
# j: (50, 66, 82)
# starting segmentation...
# Elapsed time: 5.221 seconds.
# 29
# Patient-id: 37042652
# right
# j: (57, 67, 51)
# starting segmentation...
# Elapsed time: 6.337 seconds.
# 30
# Patient-id: 37137615
# left
# j: (43, 49, 64)
# starting segmentation...
# Elapsed time: 4.022 seconds.
# 31
# Patient-id: 37137615
# right
# j: (44, 49, 38)
# starting segmentation...
# Elapsed time: 4.620 seconds.
# 32
# Patient-id: 37173796
# left
# j: (40, 54, 63)
# starting segmentation...
# Elapsed time: 3.972 seconds.
# 33
# Patient-id: 37173796
# right
# j: (43, 55, 37)
# starting segmentation...
# Elapsed time: 3.808 seconds.
# 34
# Patient-id: 37468094
# left
# j: (81, 49, 63)
# starting segmentation...
# Elapsed time: 4.608 seconds.
# 35
# Patient-id: 37468094
# right
# j: (79, 50, 37)
# starting segmentation...
# Elapsed time: 5.742 seconds.
# 36
# Patient-id: 37606125
# left
# j: (48, 55, 66)
# starting segmentation...
# Elapsed time: 3.656 seconds.
# 37
# Patient-id: 37606125
# right
# j: (47, 55, 38)
# starting segmentation...
# Elapsed time: 4.812 seconds.
# 38
# Patient-id: 37624458
# left
# j: (130, 54, 64)
# starting segmentation...
# Elapsed time: 15.898 seconds.
# 39
# Patient-id: 37624458
# right
# j: (141, 54, 36)
# starting segmentation...
# Elapsed time: 21.682 seconds.
# 40
# Patient-id: 37650357
# left
# j: (88, 60, 65)
# starting segmentation...
# Elapsed time: 6.432 seconds.
# 41
# Patient-id: 37650357
# right
# j: (82, 60, 40)
# starting segmentation...
# Elapsed time: 8.022 seconds.
# 42
# Patient-id: 37683143
# left
# j: (42, 55, 65)
# starting segmentation...
# Elapsed time: 2.850 seconds.
# 43
# Patient-id: 37683143
# right
# j: (48, 56, 36)
# starting segmentation...
# Elapsed time: 22.097 seconds.
# 44
# Patient-id: 37881605
# left
# C:\Anaconda3\lib\site-packages\scipy\ndimage\interpolation.py:605: UserWarning: From scipy 0.13.0, the output shape of zoom() is calculated with round() instead of int() - for these inputs the size of the returned array has changed.
#   "the returned array has changed.", UserWarning)
# j: (60, 55, 66)
# starting segmentation...
# Elapsed time: 26.822 seconds.
# 45
# Patient-id: 37881605
# right
# j: (58, 56, 39)
# starting segmentation...
# Elapsed time: 30.988 seconds.
# 46
# Patient-id: 37953385
# left
# j: (52, 52, 64)
# starting segmentation...
# Elapsed time: 18.426 seconds.
# 47
# Patient-id: 37953385
# right
# j: (53, 52, 38)
# starting segmentation...
# Elapsed time: 22.275 seconds.
# 48
# Patient-id: 38028657
# left
# j: (50, 50, 64)
# starting segmentation...
# Elapsed time: 0.120 seconds.
# 49
# Patient-id: 38028657
# right
# j: (46, 49, 36)
# starting segmentation...
# Elapsed time: 224.056 seconds.
# 50
# Patient-id: 38133514
# left
# j: (56, 62, 64)
# starting segmentation...
# Elapsed time: 8.461 seconds.
# 51
# Patient-id: 38133514
# right
# j: (36, 62, 36)
# starting segmentation...
# Elapsed time: 10.479 seconds.
# 52
# Patient-id: 38564873
# left
# j: (50, 54, 64)
# starting segmentation...
# Elapsed time: 8.550 seconds.
# 53
# Patient-id: 38564873
# right
# j: (50, 54, 35)
# starting segmentation...
# Elapsed time: 10.811 seconds.
# 54
# Patient-id: 39002828
# left
# j: (156, 56, 69)
# starting segmentation...
# Elapsed time: 12.982 seconds.
# 55
# Patient-id: 39002828
# right
# j: (148, 56, 43)
# starting segmentation...
# Elapsed time: 18.362 seconds.
# 56
# Patient-id: 39137852
# left
# j: (39, 57, 62)
# starting segmentation...
# Elapsed time: 3.267 seconds.
# 57
# Patient-id: 39137852
# right
# j: (38, 57, 37)
# starting segmentation...
# Elapsed time: 3.547 seconds.
# 58
# Patient-id: 39256095
# left
# j: (130, 66, 65)
# starting segmentation...
# Elapsed time: 16.941 seconds.
# 59
# Patient-id: 39256095
# right
# j: (143, 66, 38)
# starting segmentation...
# Elapsed time: 24.923 seconds.
# 60
# Patient-id: 39524591
# left
# j: (43, 55, 62)
# starting segmentation...
# Elapsed time: 2.110 seconds.
# 61
# Patient-id: 39524591
# right
# j: (53, 55, 37)
# starting segmentation...
# Elapsed time: 2.784 seconds.
# 62
# Patient-id: 39819471
# left
# j: (44, 63, 65)
# starting segmentation...
# Elapsed time: 4.635 seconds.
# 63
# Patient-id: 39819471
# right
# j: (47, 63, 43)
# starting segmentation...
# Elapsed time: 0.028 seconds.
# 64
# Patient-id: 39844012
# left
# j: (37, 48, 66)
# starting segmentation...
# Elapsed time: 4.048 seconds.
# 65
# Patient-id: 39844012
# right
# j: (38, 48, 38)
# starting segmentation...
# Elapsed time: 4.453 seconds.
# 66
# Patient-id: 39859629
# left
# j: (68, 56, 65)
# starting segmentation...
# Elapsed time: 2.924 seconds.
# 67
# Patient-id: 39859629
# right
# j: (79, 56, 40)
# starting segmentation...
# Elapsed time: 3.608 seconds.
# 68
# Patient-id: 39929954
# left
# j: (40, 52, 61)
# starting segmentation...
# Elapsed time: 4.667 seconds.
# 69
# Patient-id: 39929954
# right
# j: (50, 52, 36)
# starting segmentation...
# Elapsed time: 6.682 seconds.
# 70
# Patient-id: 39980297
# left
# j: (58, 74, 79)
# starting segmentation...
# Elapsed time: 5.717 seconds.
# 71
# Patient-id: 39980297
# right
# j: (59, 74, 52)
# starting segmentation...
# Elapsed time: 8.182 seconds.
# 72
# Patient-id: 40165373
# left
# j: (53, 66, 78)
# starting segmentation...
# Elapsed time: 5.216 seconds.
# 73
# Patient-id: 40165373
# right
# j: (71, 66, 52)
# starting segmentation...
# Elapsed time: 7.305 seconds.
# 74
# Patient-id: 40283713
# left
# j: (69, 73, 80)
# starting segmentation...
# Elapsed time: 7.822 seconds.
# 75
# Patient-id: 40283713
# right
# j: (66, 73, 52)
# starting segmentation...
# Elapsed time: 8.143 seconds.
# 76
# Patient-id: 40433190
# right
# j: (69, 52, 38)
# starting segmentation...
# Elapsed time: 2.505 seconds.
# 77
# Patient-id: 40470341
# left
# j: (61, 55, 65)
# starting segmentation...
# Elapsed time: 3.141 seconds.
# 78
# Patient-id: 40470341
# right
# j: (61, 55, 35)
# starting segmentation...
# Elapsed time: 3.873 seconds.
# 79
# Patient-id: 40584316
# left
# j: (69, 55, 63)
# starting segmentation...
# Elapsed time: 7.817 seconds.
# 80
# Patient-id: 40584316
# right
# j: (87, 55, 38)
# starting segmentation...
# Elapsed time: 9.330 seconds.
# 81
# Patient-id: 41265741
# left
# j: (153, 54, 62)
# starting segmentation...
# Elapsed time: 16.020 seconds.
# 82
# Patient-id: 41265741
# right
# j: (153, 54, 38)
# starting segmentation...
# Elapsed time: 19.710 seconds.
# 83
# Patient-id: 42242822
# left
# j: (42, 57, 62)
# starting segmentation...
# Elapsed time: 11.412 seconds.
# 84
# Patient-id: 42715988
# left
# j: (77, 61, 62)
# starting segmentation...
# Elapsed time: 6.912 seconds.
# 85
# Patient-id: 42715988
# right
# j: (79, 61, 39)
# starting segmentation...
# Elapsed time: 9.053 seconds.
# 86
# Patient-id: 43109032
# left
# j: (34, 56, 58)
# starting segmentation...
# Elapsed time: 2.129 seconds.
# 87
# Patient-id: 43109032
# right
# j: (41, 56, 30)
# starting segmentation...
# Elapsed time: 3.476 seconds.
# 88
# Patient-id: 43151324
# left
# j: (56, 59, 64)
# starting segmentation...
# Elapsed time: 2.188 seconds.
# 89
# Patient-id: 43151324
# right
# j: (63, 59, 36)
# starting segmentation...
# Elapsed time: 4.348 seconds.
# 90
# Patient-id: 43181879
# left
# j: (70, 56, 66)
# starting segmentation...
# Elapsed time: 3.055 seconds.
# 91
# Patient-id: 43181879
# right
# j: (74, 56, 37)
# starting segmentation...
# Elapsed time: 4.318 seconds.
# 92
# Patient-id: 43266075
# left
# j: (54, 71, 80)
# starting segmentation...
# Elapsed time: 4.897 seconds.
# 93
# Patient-id: 43266075
# right
# j: (55, 72, 54)
# starting segmentation...
# Elapsed time: 7.094 seconds.
# 94
# Patient-id: 43405561
# left
# j: (48, 61, 61)
# starting segmentation...
# Elapsed time: 6.468 seconds.
# 95
# Patient-id: 43405561
# right
# j: (48, 60, 38)
# starting segmentation...
# Elapsed time: 0.016 seconds.
# 96
# Patient-id: 43675706
# left
# j: (55, 65, 77)
# starting segmentation...
# Elapsed time: 6.449 seconds.
# 97
# Patient-id: 43675706
# right
# j: (58, 64, 52)
# starting segmentation...
# Elapsed time: 7.881 seconds.
# 98
# Patient-id: 44120063
# left
# j: (50, 55, 64)
# starting segmentation...
# Elapsed time: 3.856 seconds.
# 99
# Patient-id: 44120063
# right
# j: (43, 55, 38)
# starting segmentation...
# Elapsed time: 4.354 seconds.
# 100
# Patient-id: 44253050
# left
# j: (135, 60, 61)
# starting segmentation...
# Elapsed time: 10.499 seconds.
# 101
# Patient-id: 44253050
# right
# j: (153, 60, 39)
# starting segmentation...
# Elapsed time: 12.923 seconds.
# 102
# Patient-id: 44422897
# left
# j: (62, 69, 80)
# starting segmentation...
# Elapsed time: 0.024 seconds.
# 103
# Patient-id: 44422897
# right
# j: (63, 69, 51)
# starting segmentation...
# Elapsed time: 8.954 seconds.
# 104
# Patient-id: 45858788
# left
# j: (61, 63, 64)
# starting segmentation...
# Elapsed time: 3.500 seconds.
# 105
# Patient-id: 45858788
# right
# j: (52, 63, 38)
# starting segmentation...
# Elapsed time: 4.813 seconds.
# 106
# Patient-id: 46318956
# left
# j: (69, 73, 81)
# starting segmentation...
# Elapsed time: 30.160 seconds.
# 107
# Patient-id: 46318956
# right
# j: (69, 73, 54)
# starting segmentation...
# Elapsed time: 7.560 seconds.
# 108
# Patient-id: 47262863
# left
# j: (47, 52, 67)
# starting segmentation...
# Elapsed time: 5.710 seconds.
# 109
# Patient-id: 47262863
# right
# j: (57, 52, 38)
# starting segmentation...
# Elapsed time: 7.142 seconds.
# 110
# Patient-id: 47295940
# left
# j: (36, 62, 60)
# starting segmentation...
# Elapsed time: 3.523 seconds.
# 111
# Patient-id: 47295940
# right
# j: (43, 62, 39)
# starting segmentation...
# Elapsed time: 4.107 seconds.
# 112
# Patient-id: 48148279
# left
# j: (48, 50, 67)
# starting segmentation...
# Elapsed time: 4.793 seconds.
# 113
# Patient-id: 48148279
# right
# j: (47, 50, 34)
# starting segmentation...
# Elapsed time: 5.431 seconds.
# 114
# Patient-id: 48259441
# left
# Im zero
# Im zero
# j: (91, 132, 155)
# starting segmentation...
# Elapsed time: 174.345 seconds.
# 115
# Patient-id: 48259441
# right
# Im zero
# Im zero
# j: (97, 132, 103)
# starting segmentation...
# Elapsed time: 153.081 seconds.
# 116
# Patient-id: 48335198
# right
# j: (166, 63, 41)
# starting segmentation...
# Elapsed time: 10.056 seconds.
# 117
# Patient-id: 48389421
# left
# j: (51, 52, 62)
# starting segmentation...
# Elapsed time: 2.164 seconds.
# 118
# Patient-id: 48389421
# right
# j: (54, 50, 39)
# starting segmentation...
# Elapsed time: 2.548 seconds.
# 119
# Patient-id: 48684980
# left
# j: (45, 53, 65)
# starting segmentation...
# Elapsed time: 2.308 seconds.
# 120
# Patient-id: 48684980
# right
# j: (40, 53, 38)
# starting segmentation...
# Elapsed time: 2.851 seconds.
# 121
# Patient-id: 49174830
# left
# j: (70, 69, 63)
# starting segmentation...
# Elapsed time: 3.179 seconds.
# 122
# Patient-id: 49174830
# right
# j: (71, 69, 39)
# starting segmentation...
# Elapsed time: 3.930 seconds.
# 123
# Patient-id: 51927593
# right
# Im zero
# Im zero
# j: (75, 150, 102)
# starting segmentation...
# Elapsed time: 72.900 seconds.
# 124
# Patient-id: 52016057
# left
# j: (61, 73, 81)
# starting segmentation...
# Elapsed time: 6.816 seconds.
# 125
# Patient-id: 52016057
# right
# j: (63, 73, 50)
# starting segmentation...
# Elapsed time: 7.850 seconds.
# 126
# Patient-id: 52075421
# left
# j: (40, 54, 64)
# starting segmentation...
# Elapsed time: 2.864 seconds.
# 127
# Patient-id: 52075421
# right
# j: (39, 54, 40)
# starting segmentation...
# Elapsed time: 3.809 seconds.
# 128
# Patient-id: 54828475
# left
# j: (54, 67, 77)
# starting segmentation...
# Elapsed time: 4.491 seconds.
# 129
# Patient-id: 54828475
# right
# j: (54, 67, 52)
# starting segmentation...
# Elapsed time: 5.906 seconds.
# 130
# Patient-id: 57220883
# left
# j: (41, 50, 69)
# starting segmentation...
# Elapsed time: 3.181 seconds.
# 131
# Patient-id: 57220883
# right
# j: (42, 49, 37)
# starting segmentation...
# Elapsed time: 3.773 seconds.

# %%
from segmentation_functions import resample,grow
from .finding_biggest_lung import arrange_slices, normalization, get_pixels_hu,creating_mask
from seed_evaluation import evaluate_seed
import scipy.ndimage.interpolation as inter
import numpy as np
import os
import matplotlib.pyplot as plt
import scipy.io as spio
import pydicom
import time


slices_path = "G:/CTimages/"
indices_path ="G:/Results/Lungs Masks indexes/ok/Separated Lungs"
separation_path = "G:/Results/Separator/"
segmentations_results_path = "G:/Plans/CT/Lungs/segmentation_results/third/"
seeds_path = "G:/CTimages/CT/Images/Seeds/"

indices_folder= os.listdir(indices_path)
# Results of seeding method 
results = []

patient_id = "47295940"#each_mask.split(" ", each_mask.count(each_mask))[0] 
opened = spio.loadmat(indices_path+'/' +str(patient_id)+' - ct_right_lung_coordinates', squeeze_me=True)["indexes"]
slices= arrange_slices(slices_path,patient_id)
normalized_volume=normalization(slices)
normalized_array = np.array(normalized_volume)
volume_resampled, spacing = resample(normalized_array, slices, [5,5,5])

seed_1 = spio.loadmat(seeds_path+'/'+patient_id+'_seed1', squeeze_me=True)["seed1"]
seed_2 = spio.loadmat(seeds_path+'/'+patient_id+'_seed2', squeeze_me=True)["seed2"]
#pre_region = each_mask.split("_", each_mask.count(each_mask))[1]
#region = pre_region.split("_", pre_region.count(pre_region))[0] 
region = 'right'
print(region)

if region=='left':
    seeds = [seed_2]
elif region =='right':
    seeds = [seed_1]

print(seeds)
mask = creating_mask(seeds,normalized_array)
mask_resampled, spacing = resample(mask, slices, [5,5,5])
    
j = np.unravel_index(np.argmax(mask_resampled), mask_resampled.shape) #tupla
print('j: '+str(j))
seeds= [j] #lista

interval = volume_resampled.copy()
interval[j]=5000
plt.imshow(interval[:,j[1],:])
plt.show()

pre_seed = tuple(seeds)
thresh = 300
evaluation = evaluate_seed(seeds[0], opened, slices, normalized_array, region, patient_id)
#seg = np.zeros(volume_resampled.shape, dtype=np.bool)
#seg, counter = grow_things(volume_resampled,pre_seed[0],thresh,1,seg)
#plt.imshow(seg[:,50,:])

# %%
for i in range(seg.shape[1]):
    plt.imshow(seg[:,i,:])
    plt.show()
    print(i)
    time.sleep(1)
